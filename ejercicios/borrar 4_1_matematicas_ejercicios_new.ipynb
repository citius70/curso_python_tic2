# %% [markdown]
# # Ejercicios: Operaciones matemáticas
# En este notebook practicarás operaciones matemáticas y el uso de las bibliotecas `math` y `statistics`.

# %% [markdown]
# :::{exercise}
# :label: math-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Realizar operaciones básicas con números.
#
# **Ejemplo de referencia**:
# ```
# a = 10
# b = 4
# resultado_suma = a + b
# resultado_resta = a - b
# resultado_multiplicacion = a * b
# resultado_division = a / b
# print(f"Suma: {resultado_suma}")
# print(f"Resta: {resultado_resta}")
# print(f"Multiplicación: {resultado_multiplicacion}")
# print(f"División: {resultado_division}")
# ```
#
# **Instrucciones**:
# 1. Define dos números `num1` y `num2`.
# 2. Calcula y muestra en pantalla la suma, resta, multiplicación y división.
# 3. Forma la respuesta en la celda de código abajo.

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# :::{exercise}
# :label: math-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Uso de funciones trigonométricas y constantes de `math`.
#
# **Ejemplo de referencia**:
# ```
# import math
# grado = 45
# rad = math.radians(grado)
# seno = math.sin(rad)
# coseno = math.cos(rad)
# print(f"Seno: {seno:.2f}")
# print(f"Coseno: {coseno:.2f}")
# ```
#
# **Instrucciones**:
# 1. Define un valor en grados (p.ej. 30).
# 2. Convierte a radianes.
# 3. Calcula el seno y coseno.
# 4. Muestra los resultados usando `print()` con formato.
#
# Escribe tu código abajo:
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# :::exercise
# :label: math-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Uso de funciones estadísticas con `statistics`.
#
# **Ejemplo de referencia**:
# ```
# import statistics
# datos = [10, 12, 12, 15, 20]
# media = statistics.mean(datos)
# mediana = statistics.median(datos)
# moda = statistics.mode(datos)
# stdev = statistics.stdev(datos)
# print(f"Media: {media}")
# print(f"Mediana: {mediana}")
# print(f"Moda: {moda}")
# print(f"Desviación estándar: {stdev:.2f}")
# ```
#
# **Instrucciones**:
# 1. Crea una lista `valores` con al menos 5 números.
# 2. Calcula y muestra la media, mediana, moda y desviación estándar.
# 3. Usa `print()` para mostrar los resultados.
# 4. Explica en comentarios qué hace cada función.
#
# Código para completar:
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# :::exercise
# :label: math-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Cálculos con raíces y potencias.
#
# **Ejemplo de referencia**:
# ```
# import math
# x = 16
# raiz = math.sqrt(x)
# potencia = math.pow(2, 8)
# print(f\"Raíz cuadrada de {x} = {raiz:.2f}\")
# print(f\"2 elevado a 8 = {potencia}\")
# ```
#
# **Instrucciones**:
# 1. Calcula la raíz cuadrada de un número de tu elección.
# 2. Calcula 3 elevado a la potencia 4.
# 3. Muestra ambas respuestas en pantalla con `print()` y formato.
#
# Código a completar:
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# :::exercise
# :label: math-ejercicio-5
# :class: ejercicio-practico
#
# **Objetivo**: Uso de funciones logarítmicas y redondeo.
#
# **Ejemplo de referencia**:
# ```
# import math
# log_x = math.log(1000, 10)
# round_num = round(3.14159, 2)
# print(f"Logaritmo base 10 de 1000: {log_x}")
# print(f"Redondeo a 2 decimales: {round_num}")
# ```
#
# **Instrucciones**:
# 1. Calcula el logaritmo base 10 de 10000.
# 2. Redondea el número π (`math.pi`) a 3 decimales.
# 3. Muestra los resultados en pantalla.
#
# Código para completar:
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
