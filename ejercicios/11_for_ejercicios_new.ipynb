# %% [markdown]
# # Ejercicios: bucle for

# %% [markdown]
# ## Ejercicio Resuelto
#
# **Imprimir números del 1 al 10**
#
# Escribe un programa que imprima los números del 1 al 10 utilizando un bucle `for`.
#
# ```python
# # Imprimir números del 1 al 10
# for numero in range(1, 11):
#     print(numero)

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-1
# :class: ejercicio-practico
#
#
# **Objetivo**: Imprimir Números del 5 al 12
#
# * Escribe un programa que imprima los números del 5 al 12 utilizando un bucle `for`.

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir una lista de frutas
#
# * Escribe un programa que tenga una lista de seis grupos de música o cantantes y use un bucle for para imprimir cada grupo o cantante en la lista.

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Tabla de multiplicar
#
# * Escribe un programa que pida al usuario un número y luego imprima la tabla de multiplicar de ese número del 1 al 10.

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Contar vocales
#
# * Escribe un programa que pida al usuario una frase y cuente cuántas vocales hay en ella utilizando un bucle for.
