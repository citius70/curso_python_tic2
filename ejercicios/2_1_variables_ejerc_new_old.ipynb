# %% [markdown]
# # Ejercicios: Variables

# %% [markdown]
# En este notebook, practicarás la asignación de variables en Python. Completa los ejercicios.

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-1-df
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la asignación de variables numéricas en Python.
#
# **Ejemplo de referencia**:
# ```{code-block} python
# :linenos:
# # Asignación de un valor numérico a una variable
# edad = 25
#
# # Mostrar el valor de la variable
# print(edad)  # Resultado: 25
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable llamada `age`
# 2. Asígnale tu edad actual (como número)
# 3. Usa la función `print()` para mostrar el valor de la variable
#
# **Escribe tu solución en la celda de código siguiente**:
#
# ```python
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %% [markdown]
# ## Ejercicio 1:
# Ejemplo: Aquí se asigna el valor `25` a la variable `edad`. Después se muestra el valor de la variable.
# ```
# # Ejemplo
# edad = 25
# print(edad)  # Resultado: 25
# ```
# **Ejercicio** : Crea una variable `age` y asígnale tu edad. Luego, muéstrala por pantalla usando `print()`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 2: Asignación de un texto
# Ejemplo: Se asigna el valor `Juan` a la variable `nombre`. Luego, muestra el valor de la variable.
# ```
# # Ejemplo
# nombre = "Juan"
# print(nombre)  # Resultado: Juan
# ```
# **Ejercicio**: Crea una variable `name` y asígnale el valor de tu nombre. Muestra su valor con `print()`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 3: Elección de nombre de variable
# Selecciona un nombre apropiado para una variable que almacene tu nombre y apellidos, utilizando los estilos **snake_case** y **camelCase**. Escribe ejemplos con ambos estilos y muestra el valor.
# ```
# # Ejemplo
# nombre_completo = "Lucas Ruiz"
# print(nombre_completo)
# nombreCompleto = "Lucas Ruiz"
# print(nombreCompleto)
# ```

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 4: Asignación de una lista
# Ejemplo: Se crea una variable llamada `frutas` y se asigna una **lista** de tus frutas favoritas. Luego, muestra el valor de la variable.
# ```
# # Ejemplo
# frutas = ["manzana", "banana", "naranja"]
# print(frutas)
# ```
# **Ejercicio 1**: Crea una variable `canciones` y asígnale una lista de tres canciones favoritas.
#
# **Ejercicio 2**: Crea una variable `notas_asignaturas` y asígnale cuatro calificaciones. Muestra ambas listas.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 5: Asignación de múltiples variables en una línea
# Ejemplo: Se asigna valores a tres variables diferentes: `x`, `y`, y `z`. Luego, muestra el valor de cada variable.
# ```
# # Ejemplo
# x, y, z = 10, 20, 30
# print(x, y, z)
# ```
# **Ejercicio**: Crea tres variables `nota_musica`, `nota_historia`, `nota_matematicas` y asígnales tres valores. Imprime sus valores en una sola línea.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 6: Incremento y decremento de variables
# Ejemplo: Crea una variable llamada `contador` y asígnale el valor 0. Luego incrementa su valor en 1 y muestra el nuevo valor.
# ```
# contador = 0
# contador += 1
# print(contador)  # Resultado: 1
# ```
# **Ejercicio 1**: Crea una variable `conteo` con valor 10, incrementa su valor en 2 y muestra el resultado.
#
# **Ejercicio 2**: Crea una variable `decremento` con valor 7, disminuye su valor en 3 y muestra el resultado.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 7: Concatenación de cadenas
# Ejemplo: Crea dos variables de texto, `saludo` y `nombre`, y luego crea una nueva variable llamada `mensaje` que combine ambas.
# ```
# saludo = "Hola"
# nombre = "Juan"
# mensaje = saludo + ", " + nombre + "!"
# print(mensaje)  # Resultado: Hola, Juan!
# ```
# **Ejercicio**: Crea una variable `name` con tu nombre y otra `age` con tu edad. Ahora una variable `frase` que combine las anteriores en una frase. Usa `print()` para mostrar el mensaje.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 8: Conversión de variables
# 1. Crea una variable float que almacene la **gravedad en la luna** (por ejemplo, `1.62`).
# 2. Convierte la variable anterior en un entero y guárdala en otra variable (por ejemplo, `gravedad_entera`).
# 3. Muestra el valor de la nueva variable.
# 4. Añade una línea usando `type()` para comprobar el tipo final de la variable.
# ```
# # Ejemplo
# gravedad_luna = 1.62
# gravedad_entera = int(gravedad_luna)
# print(gravedad_entera)        # Resultado: 1
# print(type(gravedad_entera))  # Resultado: <class 'int'>
# ```

# %%
# Escribe tu código aquí:

# %% [markdown]
# ### Conclusión
# En este notebook, has practicado la asignación de **variables** en Python. Intenta crear más variables y experimentar con diferentes tipos de datos y conversiones usando siempre `print()` para comprobar los resultados.
