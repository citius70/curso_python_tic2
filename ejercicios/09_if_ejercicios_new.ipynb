# %% [markdown]
# # Ejercicios: if, elif, else
#
# En este notebook practicarás el uso de la estructura condicional **`if...elif...else`** en Python. Completa los ejercicios.

# %% [markdown]
# ## Ejercicio resuelto
#
# **Verificación de mayoría de edad**
#
# Programa que pide al usuario su edad y verifica si es mayor de edad (18 años o más).
#
# ```
# # Solicitar la edad del usuario
# edad = int(input("¿Cuál es tu edad? "))
#
# # Verificar si es mayor de edad
# if edad >= 18:
#     print("Puedes votar, eres mayor de edad.")
# else:
#     print("No puedes votar, eres menor de edad.")
# ```

# %% [markdown]
# ::: {exercise}
# :label: if-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Practicar el uso de `if` y `else` para comprobar si una calificación es aprobada o suspensa.
#
# **Ejemplo de referencia**:
# ```
# nota = 7
# if nota >= 5:
#     print("Has aprobado.")
# else:
#     print("Has suspendido.")
# ```
#
# **Instrucciones del ejercicio**:
# 1. Solicita al usuario una calificación entre 0 y 10 usando `input()` y conviértela a `float`.
# 2. Si la calificación es mayor o igual que 5, muestra el mensaje: `Has aprobado`.
# 3. Si es menor que 5, muestra el mensaje: `Has suspendido`.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# ::: {exercise}
# :label: if-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Determinar si un número es par o impar utilizando el operador módulo `%`.
#
# **Ejemplo de referencia**:
# ```
# numero = 4
# if numero % 2 == 0:
#     print("El número es par.")
# else:
#     print("El número es impar.")
# ```
#
# **Instrucciones del ejercicio**:
# 1. Solicita al usuario un número entero usando `input()` y conviértelo a `int`.
# 2. Usa `if` y `else` para comprobar si el número es par o impar.
# 3. Muestra un mensaje adecuado, por ejemplo: `8 es par` o `7 es impar`.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# ::: {exercise}
# :label: if-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Comparar dos números y decidir cuál es mayor o si son iguales.
#
# **Ejemplo de referencia**:
# ```
# a = 10
# b = 7
# if a > b:
#     print("a es mayor que b")
# elif a < b:
#     print("a es menor que b")
# else:
#     print("a y b son iguales")
# ```
#
# **Instrucciones del ejercicio**:
# 1. Solicita al usuario dos números (pueden ser decimales) y conviértelos a `float`.
# 2. Usa `if`, `elif` y `else` para:
#    - Mostrar un mensaje si el primer número es mayor.
#    - Mostrar un mensaje si el segundo número es mayor.
#    - Mostrar un mensaje si son iguales.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓

# %% [markdown]
# ::: {exercise}
# :label: if-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Clasificar la edad de una persona en categorías usando varias ramas `elif`.
#
# **Ejemplo de referencia**:
# ```
# edad = 16
# if edad < 12:
#     print("Niño")
# elif edad < 18:
#     print("Adolescente")
# elif edad < 65:
#     print("Adulto")
# else:
#     print("Anciano")
# ```
#
# **Instrucciones del ejercicio**:
# 1. Solicita al usuario su edad con `input()` y conviértela a `int`.
# 2. Clasifica la edad en una de estas categorías y muestra un mensaje acorde:
#    - `Niño` si la edad es menor que 12.
#    - `Adolescente` si la edad está entre 12 y 17.
#    - `Adulto` si la edad está entre 18 y 64.
#    - `Anciano` si la edad es 65 o más.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
