# %% [markdown]
# # Ejercicios: función `print()`
#
# En este notebook, practicarás el uso de la función `print()` en Python. Completa los ejercicios.

# %% [markdown]
# :::{exercise}
# :label: print-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la función `print()` con un mensaje simple.
#
# **Ejemplo de referencia**:
# ```
# print("¡Hola, mundo!")
# # Resultado: ¡Hola, mundo!
# ```
#
# **Instrucciones del ejercicio**:
# 1. Usa la función `print()` para mostrar el mensaje **"¡Hola, mundo!"** en la consola.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: print-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir múltiples valores usando `print()`.
#
# **Ejemplo de referencia**:
# ```
# nombre = "Juan"
# edad = 25
# print("Mi nombre es", nombre, "y tengo", edad, "años")
# # Resultado: Mi nombre es Juan y tengo 25 años
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea dos variables: `name` con tu nombre y `age` con tu edad.
# 2. Usa `print()` para mostrar una frase como: "Mi nombre es [nombre] y tengo [edad] años".
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: print-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Usar f-strings para imprimir con formato.
#
# **Ejemplo de referencia**:
# ```
# radio = 5
# pi = 3.1416
# area = pi * radio ** 2
# print(f"El área del círculo es: {area:.2f}")
# # Resultado: El área del círculo es: 78.54
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea las variables `radio = 7` y `pi = 3.1416`.
# 2. Calcula el área del círculo: `area = pi * radio ** 2`.
# 3. Usa un f-string para mostrar: "El área del círculo con radio 7 es X.XX" (con 2 decimales).
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: print-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir texto en varias líneas.
#
# **Ejemplo de referencia**:
# ```
# print("Primera línea")
# print("Segunda línea")
# print("Tercera línea")
# ```
#
# **Instrucciones del ejercicio**:
# Usa la función `print()` para mostrar **los cuatro primeros versos de "La canción del pirata" de Espronceda**:
#
# > ¡Que es mi barco mi tesoro!
# > ¡Que es mi dios la libertad!
# > ¡Mi ley, la fuerza y el viento!
# > ¡Mi única patria, la muerte!
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: print-ejercicio-5
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir listas y estructuras de datos.
#
# **Ejemplo de referencia**:
# ```
# frutas = ["manzana", "banana", "naranja"]
# print(frutas)
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una lista llamada `frutas` con **cinco frutas**.
# 2. Usa `print()` para mostrar la lista completa.
#
# **Escribe tu solución en la celda de código siguiente**:
# ```
# # ↓↓↓ ESCRIBE TU CÓDIGO AQUÍ ↓↓↓
# ```
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ
