# %% [markdown]
# # Ejercicios: Variables

# %% [markdown]
# En este notebook, practicarás la asignación de **variables** en Python. Completa los ejercicios.

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la asignación de variables numéricas en Python.
#
# **Ejemplo de referencia**:
# ```
# edad = 25
# print(edad) # Resultado: 25
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable llamada `age`
# 2. Asígnale tu edad actual (como número)
# 3. Usa la función `print()` para mostrar el valor de la variable
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la asignación de variables de tipo texto en Python.
#
# **Ejemplo de referencia**:
# ```
# nombre = "Juan"
# print(nombre) # Resultado: Juan
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable llamada `name`
# 2. Asígnale el valor de tu nombre (como texto)
# 3. Usa la función `print()` para mostrar el valor de la variable
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Practicar estilos de nombres de variables (snake_case y camelCase).
#
# **Ejemplo de referencia**:
# ```
# nombre_completo = "Lucas Ruiz"
# print(nombre_completo)
# nombreCompleto = "Lucas Ruiz"
# print(nombreCompleto)
# ```
#
# **Instrucciones del ejercicio**:
# 1. Define una variable con tu nombre y apellidos usando **snake_case**
# 2. Define otra variable con tu nombre y apellidos usando **camelCase**
# 3. Muestra el valor de ambas variables con `print()`
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-4
# :class: ejercicio-practico
#
#
#
# **Objetivo**: Practicar listas y asignación múltiple en Python.
#
# **Ejemplo de referencia**:
# ```
# frutas = ["manzana", "banana", "naranja"]
# print(frutas)
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable `canciones` con una lista de tres canciones favoritas
# 2. Crea otra variable `notas_asignaturas` con cuatro calificaciones
# 3. Muestra ambas listas con `print()`
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-5
# :class: ejercicio-practico
#
# **Objetivo**: Asignar múltiples variables en una sola línea.
#
# **Ejemplo de referencia**:
# ```
# x, y, z = 10, 20, 30
# print(x, y, z)
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea tres variables: `nota_musica`, `nota_historia`, `nota_matematicas`
# 2. Asígnales tres valores en una sola línea
# 3. Imprime sus valores en una sola línea
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-6
# :class: ejercicio-practico
#
# **Objetivo**: Practicar el incremento y decremento de variables.
#
# **Ejemplo de referencia**:
# ```
# contador = 0
# contador += 1
# print(contador) # Resultado: 1
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable `conteo` con valor 10, incrementa su valor en 2 y muestra el resultado
# 2. Crea una variable `decremento` con valor 7, disminuye su valor en 3 y muestra el resultado
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-7
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la concatenación de cadenas de texto.
#
# **Ejemplo de referencia**:
# ```
# saludo = "Hola"
# nombre = "Juan"
# mensaje = saludo + ", " + nombre + "!"
# print(mensaje) # Resultado: Hola, Juan!
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable `name` con tu nombre y otra `age` con tu edad
# 2. Crea una variable `frase` que combine ambas en una frase
# 3. Muestra el mensaje resultante con `print()`
#
# **Escribe tu solución en la celda de código siguiente**:
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-8
# :class: ejercicio-practico
#
# **Objetivo**: Practicar conversión de tipos de datos.
#
# **Ejemplo de referencia**:
# ```
# gravedad_luna = 1.62
# gravedad_entera = int(gravedad_luna)
# print(gravedad_entera) # Resultado: 1
# print(type(gravedad_entera)) # Resultado: <class 'int'>
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una variable float llamada `G_JUPITER` (busca en internet el valor de la gravedad de Júpiter)
# 2. Convierte la variable en un entero y guárdala en `G_JUPITER_INT`
# 3. Muestra el valor y tipo de la nueva variable con `print()`
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# :::{exercise}
# :label: variables-ejercicio-9
# :class: ejercicio-practico
#
# ---
#
#
# **Objetivo**: Inventario de artículos de papelería.
#
# **Instrucciones del ejercicio**:
#
# 1. Crea una variable `producto` con el nombre de un artículo (ej. "Libreta").
# 2. Crea una variable `cantidad` con el valor inicial de 5.
# 3. Crea una variable `precio_unitario` con el valor 3.95.
# 4. Imagina que llegan 10 unidades más; actualiza la variable `cantidad` usando el operador de incremento (`+=`).
#     ```python
#     # Las dos  formas equivalentes de hacerlo en Python:
#     cantidad = cantidad + 10
#     cantidad += 10
#     # Ahora es 15
#     ```
# 5. Calcula el `coste_total` multiplicando la cantidad por el precio (**siempre con los nombres de las variables, nunca con sus valores**).
# 6. Convierte el `coste_total` en un número entero para obtener una aproximación sin decimales y guárdalo en `coste_estimado`.
# 7. Muestra un mensaje final que **concatene** el nombre del producto con el coste estimado.
#     ```python
#     # Salida con concatenación (usando str() para el número)
#     mensaje = "El coste estimado de " + producto + " es de " + str(coste_estimado) + " euros."
#     print(mensaje)
#     ```

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---

# %% [markdown]
# ### Conclusión
# En este notebook, has practicado la asignación de **variables** en Python. Intenta crear más variables y experimentar con diferentes tipos de datos y conversiones usando siempre `print()` para comprobar los resultados.
