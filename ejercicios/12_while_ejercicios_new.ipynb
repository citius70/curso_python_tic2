# %% [markdown]
# # Ejercicios: bucle while

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-1
# :class: ejercicio-practico:
#
# ## Tabla de multiplicar
#
# **Objetivo**: Escribir un programa que muestre la tabla de multiplicar (del 1 al 10) de un número (`num`) introducido por el usuario.
#
# **Instrucciones**: Debes utilizar un bucle `while`.
#
# **Ejemplo de salida**: Si el usuario introduce el número 5, el programa debería mostrar:
#
# ```python
# 5 x 1 = 5
# 5 x 2 = 10
# ...
# 5 x 10 = 50
# ```
# **¡Ayuda!**: Copia y pega los comentarios del código que se muestra a continuación y completa el código para que el programa funcione correctamente.

# %%
# Pide un número al usuario


# Inicializa el contador en 1

# Mientras el contador sea menor o igual a 10

    # Calcula el resultado de la multiplicación

    # Imprime la línea correspondiente de latabla de multiplicar

    # Incrementa el contador en 1

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-2
# :class: ejercicio-practico:
#
# ## Hucha
#
# **Objetivo**: Escribir un programa que simule una hucha para ahorrar, utilizando el bucle `while`.
#
# **Instrucciones**:
# 1. Pide primero una cantidad que se desea ahorrar.
# 2. Luego, solicita cantidades a añadir a la hucha que se irán sumando hasta alcanzar el objetivo.
#
# **Ejemplo de salida**: Si el usuario introduce que desea ahorrar 100 euros, el programa podría mostrar:
#
# ```python
# Introduce la cantidad que deseas ahorrar: 100
# ---
# Introduce una cantidad para añadir a la hucha: 20
# Cantidad ahorrada: 20 euros. Te faltan 80 euros para alcanzar tu objetivo
# Introduce una cantidad para añadir a la hucha: 30
# Cantidad ahorrada: 50 euros. Te faltan 50 euros para alcanzar tu objetivo
# Introduce una cantidad para añadir a la hucha: 50
# ¡Felicidades! Has alcanzado tu objetivo de ahorro.
# ```
# **¡Ayuda!**: Copia y pega los comentarios del código que se muestra a continuación y completa el código para que el programa funcione correctamente.

# %%
# Se solicita al usuario que introduzca la cantidad de dinero que desea ahorrar y se almacena en la variable objetivo
# La función input() recibe un valor como cadena, y float() lo convierte a un número decimal.


# Inicializamos la variable ahorrado en 0.0, que almacenará la cantidad total ahorrada.


# Iniciamos un bucle while que continuará ejecutándose mientras el total ahorrado sea menor que el objetivo.

    # Se solicita al usuario que introduzca una cantidad de dinero para añadir a la hucha y se almacena en la variable cantidad
    
    # Añadimos la cantidad de dinero para añadir a lo ahorrado.
   
# Una vez que el total ahorrado es igual o mayor que el objetivo, salimos del bucle.
# Imprimimos un mensaje indicando que se ha alcanzado el objetivo y mostramos la cantidad total ahorrada.

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-3
# :class: ejercicio-practico:
#
# ## Control de inventario de automóviles
#
# **Objetivo**: Escribir un programa que te permita **controlar el inventario** (stock o unidades) de una tienda de automóviles, utilizando un bucle `while`.
#
# **Instrucciones**:
#
# 1. Escribe el código que te permita ingresar la **cantidad inicial** de automóviles existentes
#
# 2. Ahora debe **preguntar cuántos automóviles se vendieron** dentro de un **bucle** `while` que se ejecute **mientras el inventario sea mayor que cero**.
#
# 3.  Cada vez que vendes un automóvil, **disminuyes tu inventario**.
#
#     * Cada vez que se vende algún automóvil debe **mostrar el inventario restante** (cuántos automóviles quedan).
#
# 4. Esto debe **repetirse hasta que el inventario llegue a cero** (o menos)
#
#     * En ese momento el programa debe mostrar un **mensaje indicando que no quedan automóviles en stock**. Además, debe indicar el **número de transacciones** (ventas individuales) que se realizaron antes de que se acabara el inventario.
#
# **Ejemplo de salida**: Si el usuario introduce que hay 5 automóviles en el inventario, el programa podría mostrar:
#
# ```python
# Introduce la cantidad inicial de automóviles en el inventario: 5
# ---
# Introduce la cantidad de automóviles vendidos: 1
# Inventario restante: 4 automóviles
# Introduce la cantidad de automóviles vendidos: 2
# Inventario restante: 2 automóviles
# Introduce la cantidad de automóviles vendidos: 2
# Inventario restante: 0 automóviles
# ¡No quedan automóviles en stock! Se realizaron 3 transacciones de venta.
# ```
# **¡Ayuda!**: Copia y pega los comentarios del código que se muestra a continuación y completa el código para que el programa funcione correctamente.

# %%
# Solicitar la cantidad inicial de automóviles en stock

# Inicializar el contador de transacciones

# Comenzar un bucle que continuará hasta que el stock llegue a cero

    # Solicitar la cantidad de automóviles vendidos en la transacción actual
    
    
    # Verificar que la cantidad vendida no sea mayor que el stock disponible

         # En este caso mostrar que no se pueden vender porque no hay stock
    # Si se pueden vender...
        # Disminuir el stock con el número de automóbiles vendidos
        # Aumentar el contador de transacciones en 1
        # Mostrar que la transacción ha sido registrada y el numero de automóviles que quedan

# Una vez que el stock llega a cero, mostrar el número total de transacciones
