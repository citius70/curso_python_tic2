# %% [markdown]
# # Ejercicios de operaciones matemáticas

# %% [markdown]
# En este notebook, practicarás diferentes operaciones matemáticas utilizando Python. Completa los ejercicios a continuación.

# %% [markdown]
# ## Ejercicio 1: Suma
#
# **Ejemplo**: Aquí tienes un ejemplo en el que se declaran dos variables `a` y `b` con los valores `5` y `7`, respectivanente. a continuación, se suman ambas variables y se almacena el resultado en la variable **suma**. Escribe un código que sume dos números. Por ejemplo, suma 5 y 7.
# ```python
# a = 5
# b = 7
# suma = a + b
# print(suma)
# ```

# %% [markdown]
# **Ejercicio**: Haz lo mismo con las variables `x` e `y` , y los valores `6` y `3`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 2: Resta
# **Ejemplo**:
# ```python
# a = 25
# b = 10
# resta = a - b
# print(resta)
# ```

# %% [markdown]
# **Ejercicio**: Haz lo mismo con las variables `x` e `y` , y los valores `8` y `3`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 3: Multiplicación
# **Ejemplo**:
# ```python
# a = 4
# b = 6
# multiplicacion = a * b
# print(multiplicacion)
# ```

# %% [markdown]
# **Ejercicio**: Haz lo mismo con las variables `x` e `y` , y los valores `6` y `3`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 4: División
#
# **Ejemplo**: Código que divide dos números. Por ejemplo, divide 20 entre 4.
#
# ```python
# a = 20
# b = 4
# division = a / b
# prin(division)
# ```

# %% [markdown]
# **Ejercicio**: Haz lo mismo con las variables `x` e `y` , y los valores `10` y `2`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 5: Potencia
#
# **Ejemplo**: Código que calcula la potencia de un número. Por ejemplo, calcula 2 elevado a la 3.
#
# ```python
# base = 2
# exponente = 3
# potencia = base ** exponente
# print(potencia)
# ```

# %% [markdown]
# **Ejercicio**: Haz lo mismo con las variables `x` e `y` , y los valores `6` y `3`.

# %%
# Escribe tu código aquí:

# %% [markdown]
# **Ejercicio**: Haz lo mismo utilizando la función `pow()`

# %%
# Escribe tu código aquí:

# %% [markdown]
# ## Ejercicio 6: Biblioteca `math`

# %% [markdown]
# Escribe un programa que calcule la **hipotenusa** de un triángulo rectángulo dado los catetos. Los catetos se definirán directamente en el código:
# ```python
# catA = 50
# catB = 25
# ```
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRC6JgN6y1CIjaN4V600gebU6JzVPvLkmdOmw&s" width="300px">

# %%
# Importa la biblioteca math

# Asigna los valores de los catetos a las varaiables catA y catB


# Calcular la hipotenusa con la ayuda de math y asígna el resultado a la variable hipot


# Mostrar los resultados con print()
