# %% [markdown]
# # ijkfseed

# %% [markdown]
# :::{exercise} my-exercise
# :label: my-exercise
#
# Recall that $n!$ is read as "$n$ factorial" and defined as
# $n! = n \times (n - 1) \times \cdots \times 2 \times 1$.
#
# There are functions to compute this in various modules, but let's
# write our own version as an exercise.
#
# In particular, write a function `factorial` such that `factorial(n)` returns $n!$
# for any positive integer $n$.

# %% [markdown]
# ```{exercise}
# :label: my-exercise
#
# Recall that $n!$ is read as "$n$ factorial" and defined as
# $n! = n \times (n - 1) \times \cdots \times 2 \times 1$.
#
# There are functions to compute this in various modules, but let's
# write our own version as an exercise.
#
# In particular, write a function `factorial` such that `factorial(n)` returns $n!$
# for any positive integer $n$.
# ```

# %% [markdown]
# ```{admonition} Exercise
# :class: tip
# Recall that $n!$ is read as "$n$ factorial" and defined as
# $n! = n \times (n - 1) \times \cdots \times 2 \times 1$.
#
# Write a function `factorial(n)` that returns $n!$.
# ```

# %% [markdown]
# ```{admonition} Exercise
# :class: tip
# Escribe una función `factorial(n)` que calcule $n!$.
# ```

# %% [markdown]
# ```{note}
# Ejercicio: implementa `factorial(n)`.
# ```

# %% [markdown]
# ```{admonition} Exercise
# Escribe una función `factorial(n)` que calcule $n!$.
#
# ```{toggle} Solución
# ```python
# def factorial(n):
#     return 1 if n <= 1 else n * factorial(n-1)
# ```
# ```

# %% [markdown]
# ```{toggle} Solución
# ```python
# def factorial(n):
#     return 1 if n <= 1 else n * factorial(n-1)
# ```
# ```

# %%
def factorial(n):
    return 1 if n <= 1 else n * factorial(n-1)

factorial(5)
# Out:
# 120

# %% [markdown]
# ```{card}
# **Ejercicio**
#
# Implementa `factorial(n)`.
# ```

# %% [markdown]
# ```{exercise}
# :label: my-exercise
#
# Recall that $n!$ is read as "$n$ factorial" and defined as
# $n! = n \times (n - 1) \times \cdots \times 2 \times 1$.
#
# There are functions to compute this in various modules, but let's
# write our own version as an exercise.
#
# In particular, write a function `factorial` such that `factorial(n)` returns $n!$
# for any positive integer $n$.
# ```
